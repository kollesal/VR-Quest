# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the data to a pandas data frame
df_MediaP = pd.read_csv('../Data/samples.csv', sep=',', encoding='utf-8')
df_MediaP.head(5)
# Out:
#                                                 path  frame  compensation
# 0  bachelorarbeiten/nils/data/videos/samples/drin...      1         False  \
# 1  bachelorarbeiten/nils/data/videos/samples/drin...      2         False
# 2  bachelorarbeiten/nils/data/videos/samples/drin...      3         False
# 3  bachelorarbeiten/nils/data/videos/samples/drin...      4         False
# 4  bachelorarbeiten/nils/data/videos/samples/drin...      5         False
#
#          x_0        y_0        z_0         x_1        y_1         z_1
# 0  980.27070  321.90277 -637.87220  1001.20710  298.31467 -570.743400  \
# 1  980.18304  322.42087 -576.33840  1000.78390  298.30203 -499.956900
# 2  979.45184  322.89380 -494.81754   999.68500  298.31150 -419.451260
# 3  978.80115  323.32083 -288.78116   999.19960  298.38647 -218.547260
# 4  978.20070  323.40253 -187.49016   998.74774  298.37817 -120.181145
#
#           x_2  ...       z_29       x_30        y_30       z_30       x_31
# ...

# %%
df_MediaPInts = df_MediaP[["x_0","y_0","z_0","x_1","y_1","z_1","x_2","y_2","z_2","x_3","y_3","z_3","x_4","y_4","z_4","x_5","y_5","z_5","x_6","y_6","z_6","x_7","y_7","z_7","x_8","y_8","z_8","x_9","y_9","z_9","x_10","y_10","z_10","x_11","y_11","z_11","x_12","y_12","z_12","x_13","y_13","z_13","x_14","y_14","z_14","x_15","y_15","z_15","x_16","y_16","z_16","x_17","y_17","z_17","x_18","y_18","z_18","x_19","y_19","z_19","x_20","y_20","z_20","x_21","y_21","z_21","x_22","y_22","z_22","x_23","y_23","z_23","x_24","y_24","z_24","x_25","y_25","z_25","x_26","y_26","z_26","x_27","y_27","z_27","x_28","y_28","z_28","x_29","y_29","z_29","x_30","y_30","z_30","x_31","y_31","z_31","x_32","y_32","z_32"]]
df_MediaPInts.head(5)
# Out:
#          x_0        y_0        z_0         x_1        y_1         z_1
# 0  980.27070  321.90277 -637.87220  1001.20710  298.31467 -570.743400  \
# 1  980.18304  322.42087 -576.33840  1000.78390  298.30203 -499.956900
# 2  979.45184  322.89380 -494.81754   999.68500  298.31150 -419.451260
# 3  978.80115  323.32083 -288.78116   999.19960  298.38647 -218.547260
# 4  978.20070  323.40253 -187.49016   998.74774  298.37817 -120.181145
#
#           x_2        y_2        z_2         x_3  ...       z_29       x_30
# 0  1012.57666  298.70868 -570.96620  1021.52344  ... -608.88220  868.95660  \
# 1  1011.92860  298.70166 -500.33987  1021.06647  ... -492.89044  863.16870
# 2  1010.53424  298.71362 -419.83456  1019.88030  ... -507.46440  856.91050
# 3  1009.97040  298.80426 -218.87080  1019.47750  ... -291.10700  857.01370
# 4  1009.56600  298.77322 -120.60495  1019.22626  ... -668.87690  862.94824
#
#          y_30       z_30       x_31       y_31       z_31       x_32
# ...

# %% [markdown]
# ## Show all the Points

# %%
import matplotlib.pyplot as plt

# Extract x, y coordinates from the DataFrame
x = df_MediaPInts.iloc[:, ::3].values.flatten()
y = df_MediaPInts.iloc[:, 1::3].values.flatten()

# Create a 2D scatter plot with thinner points
plt.scatter(x, y, s=1)  # Adjust 's' to control the thickness of the points

# Set labels
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()

# %%
max_value = df_MediaPInts.values.max()
print(max_value)
# Out:
# 1856.449

# %% [markdown]
# ## Creating a (almost) Random line above the highest Value

# %%
# Create variable for line
yLine = round(max_value, -2)
xLine = round(max_value, -2)
print(yLine)
# Out:
# 1900.0

# %%
import matplotlib.pyplot as plt

# Extract x, y coordinates from the DataFrame
x = df_MediaPInts.iloc[:, ::3].values.flatten()
y = df_MediaPInts.iloc[:, 1::3].values.flatten()

# Create a 2D scatter plot with thinner points
plt.scatter(x, y, s=1)  # Adjust 's' to control the thickness of the points

# Draw a horizontal line at y = 1900
plt.axhline(y=yLine, color='r', linestyle='--')  # Adjust color and linestyle as needed

# Set labels
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()

# %% [markdown]
# ## Create nex Variables that will store the mirrored values to the Y-Line

# %%
# Calculate the difference between the original y-values and y-line
y_diff = yLine - df_MediaPInts.iloc[:, 1::3].values

# Mirror the values across the y-line
mirrored_values = yLine + y_diff

# Store the mirrored values in a new variable
mirrored_df = df_MediaPInts.copy()  # Create a copy of the original DataFrame
mirrored_df.iloc[:, 1::3] = mirrored_values  # Replace the y-values with mirrored values

# Display the mirrored DataFrame
mirrored_df.head(5)
# Out:
#          x_0         y_0        z_0         x_1         y_1         z_1
# 0  980.27070  3478.09723 -637.87220  1001.20710  3501.68533 -570.743400  \
# 1  980.18304  3477.57913 -576.33840  1000.78390  3501.69797 -499.956900
# 2  979.45184  3477.10620 -494.81754   999.68500  3501.68850 -419.451260
# 3  978.80115  3476.67917 -288.78116   999.19960  3501.61353 -218.547260
# 4  978.20070  3476.59747 -187.49016   998.74774  3501.62183 -120.181145
#
#           x_2         y_2        z_2         x_3  ...       z_29       x_30
# 0  1012.57666  3501.29132 -570.96620  1021.52344  ... -608.88220  868.95660  \
# 1  1011.92860  3501.29834 -500.33987  1021.06647  ... -492.89044  863.16870
# 2  1010.53424  3501.28638 -419.83456  1019.88030  ... -507.46440  856.91050
# 3  1009.97040  3501.19574 -218.87080  1019.47750  ... -291.10700  857.01370
# 4  1009.56600  3501.22678 -120.60495  1019.22626  ... -668.87690  862.94824
#
#          y_30       z_30       x_31        y_31       z_31       x_32
# ...

# %%
import matplotlib.pyplot as plt

# Extract x, y coordinates from the original DataFrame
x_original = df_MediaPInts.iloc[:, ::3].values.flatten()
y_original = df_MediaPInts.iloc[:, 1::3].values.flatten()

# Extract x, y coordinates from the mirrored DataFrame
x_mirrored = mirrored_df.iloc[:, ::3].values.flatten()
y_mirrored = mirrored_df.iloc[:, 1::3].values.flatten()

# Create a scatter plot for original points
plt.scatter(x_original, y_original, label='Original', s=1)

# Create a scatter plot for mirrored points
plt.scatter(x_mirrored, y_mirrored, label='Mirrored', s=1)

plt.axhline(y=yLine, color='r', linestyle='--')

# Add a legend
plt.legend()

# Set labels
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()

# %%
mirrored_df.head(5)
# Out:
#          x_0         y_0        z_0         x_1         y_1         z_1
# 0  980.27070  3478.09723 -637.87220  1001.20710  3501.68533 -570.743400  \
# 1  980.18304  3477.57913 -576.33840  1000.78390  3501.69797 -499.956900
# 2  979.45184  3477.10620 -494.81754   999.68500  3501.68850 -419.451260
# 3  978.80115  3476.67917 -288.78116   999.19960  3501.61353 -218.547260
# 4  978.20070  3476.59747 -187.49016   998.74774  3501.62183 -120.181145
#
#           x_2         y_2        z_2         x_3  ...       z_29       x_30
# 0  1012.57666  3501.29132 -570.96620  1021.52344  ... -608.88220  868.95660  \
# 1  1011.92860  3501.29834 -500.33987  1021.06647  ... -492.89044  863.16870
# 2  1010.53424  3501.28638 -419.83456  1019.88030  ... -507.46440  856.91050
# 3  1009.97040  3501.19574 -218.87080  1019.47750  ... -291.10700  857.01370
# 4  1009.56600  3501.22678 -120.60495  1019.22626  ... -668.87690  862.94824
#
#          y_30       z_30       x_31        y_31       z_31       x_32
# ...

# %%
import matplotlib.pyplot as plt

# Extract x, y coordinates from the DataFrame
x = df_MediaPInts.iloc[:, ::3].values.flatten()
y = df_MediaPInts.iloc[:, 1::3].values.flatten()

# Create a 2D scatter plot with thinner points
plt.scatter(x, y, s=1)  # Adjust 's' to control the thickness of the points

# Define the x-line value
x_line = 1900

# Draw a vertical line at x = 1900
plt.axvline(x=x_line, color='r', linestyle='--')  # Adjust color and linestyle as needed

# Set labels
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract x, y coordinates from the DataFrame
x = df_MediaPInts.iloc[:, ::3].values  # Note: Removed .flatten() to preserve shape
y = df_MediaPInts.iloc[:, 1::3].values  # Note: Removed .flatten() to preserve shape

# Calculate the difference between the original x-values and x-line
x_diff = xLine - x

# Mirror the values across the x-line
mirrored_x = xLine + x_diff

# Create a mirrored DataFrame
mirrored_df = df_MediaPInts.copy()  # Make a copy of the original DataFrame
mirrored_df.iloc[:, ::3] = mirrored_x  # Replace the x-coordinates with the mirrored x-values

# Create a 2D scatter plot with thinner points for original and mirrored points
plt.scatter(x, y, s=1, label='Original')  # Original points
plt.scatter(mirrored_x, y, s=1, label='Mirrored')  # Mirrored points

# Draw a vertical line at x = 1900
plt.axvline(x=xLine, color='r', linestyle='--')  # Adjust color and linestyle as needed

# Set labels and legend
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract x, y coordinates from the original DataFrame
x_original = df_MediaPInts.iloc[:, ::3].values.flatten()
y_original = df_MediaPInts.iloc[:, 1::3].values.flatten()

# Calculate the difference between the original y-values and y-line
y_diff = yLine - y_original

# Mirror the y-values across the y-line
mirrored_y = yLine + y_diff

# Calculate the difference between the original x-values and x-line
x_diff = xLine - x_original

# Mirror the x-values across the x-line
mirrored_x = xLine + x_diff

# Create a scatter plot for original points
plt.scatter(x_original, y_original, label='Original', s=1)

# Create a scatter plot for mirrored points
plt.scatter(mirrored_x, mirrored_y, label='Mirrored', s=1)

# Draw a horizontal line at y = 1900
plt.axhline(y=yLine, color='r', linestyle='--')

# Draw a vertical line at x = 1900
plt.axvline(x=xLine, color='b', linestyle='--')

# Add a legend
plt.legend()

# Set labels
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()

# %%
# Calculate the difference between the original y-values and y-line
y_diff = yLine - df_MediaPInts.iloc[:, 1::3]

# Mirror the y-values across the y-line
mirrored_y = yLine + y_diff

# Calculate the difference between the original x-values and x-line
x_diff = xLine - df_MediaPInts.iloc[:, ::3]

# Mirror the x-values across the x-line
mirrored_x = xLine + x_diff

# Create a DataFrame to store the mirrored points
mirrored_df = df_MediaPInts.copy()

# Replace original x-values with mirrored x-values
mirrored_df.iloc[:, ::3] = mirrored_x

# Replace original y-values with mirrored y-values
mirrored_df.iloc[:, 1::3] = mirrored_y

# Show the mirrored DataFrame
mirrored_df.head(5)
# Out:
#           x_0         y_0        z_0         x_1         y_1         z_1
# 0  2819.72930  3478.09723 -637.87220  2798.79290  3501.68533 -570.743400  \
# 1  2819.81696  3477.57913 -576.33840  2799.21610  3501.69797 -499.956900
# 2  2820.54816  3477.10620 -494.81754  2800.31500  3501.68850 -419.451260
# 3  2821.19885  3476.67917 -288.78116  2800.80040  3501.61353 -218.547260
# 4  2821.79930  3476.59747 -187.49016  2801.25226  3501.62183 -120.181145
#
#           x_2         y_2        z_2         x_3  ...       z_29        x_30
# 0  2787.42334  3501.29132 -570.96620  2778.47656  ... -608.88220  2931.04340  \
# 1  2788.07140  3501.29834 -500.33987  2778.93353  ... -492.89044  2936.83130
# 2  2789.46576  3501.28638 -419.83456  2780.11970  ... -507.46440  2943.08950
# 3  2790.02960  3501.19574 -218.87080  2780.52250  ... -291.10700  2942.98630
# 4  2790.43400  3501.22678 -120.60495  2780.77374  ... -668.87690  2937.05176
#
# ...

# %%
mirrored_df['path'] = df_MediaP['path']
mirrored_df['frame'] = df_MediaP['frame']
mirrored_df['compensation'] = df_MediaP['compensation']

path_column = mirrored_df.pop('path')
frame_column = mirrored_df.pop('frame')
compensation_column = mirrored_df.pop('compensation')

mirrored_df.insert(0, 'path', path_column)
mirrored_df.insert(0, 'frame', frame_column)
mirrored_df.insert(0, 'compensation', compensation_column)

mirrored_df.head(5)
# Out:
#    compensation  frame                                               path
# 0         False      1  bachelorarbeiten/nils/data/videos/samples/drin...  \
# 1         False      2  bachelorarbeiten/nils/data/videos/samples/drin...
# 2         False      3  bachelorarbeiten/nils/data/videos/samples/drin...
# 3         False      4  bachelorarbeiten/nils/data/videos/samples/drin...
# 4         False      5  bachelorarbeiten/nils/data/videos/samples/drin...
#
#           x_0         y_0        z_0         x_1         y_1         z_1
# 0  2819.72930  3478.09723 -637.87220  2798.79290  3501.68533 -570.743400  \
# 1  2819.81696  3477.57913 -576.33840  2799.21610  3501.69797 -499.956900
# 2  2820.54816  3477.10620 -494.81754  2800.31500  3501.68850 -419.451260
# 3  2821.19885  3476.67917 -288.78116  2800.80040  3501.61353 -218.547260
# 4  2821.79930  3476.59747 -187.49016  2801.25226  3501.62183 -120.181145
#
#           x_2  ...       z_29        x_30        y_30       z_30       x_31
# ...

# %%
mirrored_df.to_csv('../Data/samples_rotated.csv',
                           sep=",",
                           encoding='utf-8',
                           index=False)
