# %% [markdown]
# # Drinking Task Pipeline

# %% [markdown]
# Diese Pipeline führt eine Klassifikation von Trinkbewegungen durch.
#
# Die Elemente, welche angepasst werden können, um Ansätze auszuprobieren, wurden mit ✏️ gekennzeichnet.
#
# #### Geeignete Parameter (Beispiel):
#
# **3.2 Ansatz auswählen**
# - Ansatz 1: Absolute Datenpunkte mit geschnittenen Videos
# - n_frames: **38**
#
# **4.3 Modell anwenden**
# - n_neurons: **64**
# - RNN-Modell

# %% [markdown]
# # 1. Import Dependecies

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

from tensorflow import keras
from tensorflow.keras import layers

from sklearn.model_selection import RandomizedSearchCV

import math

# %% [markdown]
# # 2. Landmarks extrahieren

# %%
def extract_landmarks_normal():
    # %run extract_landmarks.py --video-dir data/video/normal --output-file data/landmarks_normal.csv

# %%
def extract_landmarks_compensation():
    # %run extract_landmarks.py --video-dir data/video/compensation --output-file data/landmarks_compensation.csv

# %%
# Falls die Landmarks neu extrahiert werden sollen, folgende Befehle auskommentieren: ✏️
# extract_landmarks_normal()
# extract_landmarks_compensation()

# %% [markdown]
# # 3. Data Pre-Processing

# %%
# Landmarks einlesen
data_normal = pd.read_csv('data/landmarks_normal.csv')
data_compensation = pd.read_csv('data/landmarks_compensation.csv')

# Label setzen (Kompensation = 1, keine Kompensation = 0)
data_compensation.compensation = 1
data_normal.compensation = 0
# Normal- und Kompensation-Liste zusammenführen
data = pd.concat([data_normal, data_compensation], axis=0)
data[data.frame == 1]
# Out:
#                                                     path  frame  compensation
# 0                       data/video/normal\01_trinken.mp4      1             0  \
# 177                     data/video/normal\02_trinken.mp4      1             0
# 402                     data/video/normal\03_trinken.mp4      1             0
# 567                     data/video/normal\04_trinken.mp4      1             0
# 781                     data/video/normal\05_trinken.mp4      1             0
# ...                                                  ...    ...           ...
# 83634  data/video/compensation\Video78_trinken_kompen...      1             1
# 83956  data/video/compensation\Video79_trinken_kompen...      1             1
# 84272  data/video/compensation\Video7_trinken_kompens...      1             1
# 84518  data/video/compensation\Video8_trinken_kompens...      1             1
# 84756  data/video/compensation\Video9_trinken_kompens...      1             1
#
#               x_0        y_0         z_0        x_1        y_1         z_1
# 0      1000.68180  327.32000  -487.17905  1015.6097  300.61502  -435.28815  \
# 177    1035.52190  347.54290  -436.01190  1050.1111  318.36487  -385.82090
# 402    1007.95110  331.92557  -505.59350  1022.3508  304.50528  -455.28450
# 567    1016.43060  327.84763  -465.54010  1031.5165  300.86203  -416.20996
# 781    1008.07654  329.05203  -417.67047  1023.1855  302.01657  -366.17880
# ...           ...        ...         ...        ...        ...         ...
# 83634   695.98150  192.09547  -738.46185   715.3987  166.06908  -694.03700
# 83956   695.62340  204.23773  -748.76840   714.3708  178.32655  -707.79550
# 84272   696.57630  205.63763  -644.05940   718.2416  171.20961  -609.75660
# 84518   691.08880  199.24748  -502.80673   712.4780  168.89493  -462.62744
# 84756   671.76874  208.60712 -1067.55910   694.8455  174.45702 -1040.79720
#
#              x_2  ...        z_29        x_30        y_30        z_30
# 0      1024.7533  ... -224.031780   886.21216  1200.91050 -312.124760  \
# 177    1059.7306  ... -258.592000  1032.71440  1069.01430  -87.714020
# 402    1031.3340  ...  -43.939630   912.39730  1181.08750 -358.936400
# 567    1040.4376  ...   10.623114   894.78330  1164.86670 -274.302760
# 781    1032.2201  ...  -38.536630   914.58090  1169.42720 -293.642100
# ...          ...  ...         ...         ...         ...         ...
# 83634   726.1747  ... -230.856600   711.55084   686.96420  -85.749280
# 83956   724.5825  ... -386.334600   737.65000   619.30023 -182.701600
# 84272   730.1854  ...  671.935400   656.40940  1211.92750  867.581670
# 84518   724.1534  ...   66.536690   695.43030  1215.82570   18.341394
# 84756   710.1508  ...  640.457100   615.00180  1229.46780  453.515380
#
#              x_31        y_31       z_31       x_32        y_32       z_32
# 0      1013.16100  1197.84010 -452.02050  807.56680  1270.23230 -595.89825
# 177    1141.13040  1242.84670 -498.39038  977.26056  1183.31340 -286.18155
# 402    1018.88696  1151.87520 -228.02023  837.38586  1256.53910 -640.50390
# 567    1032.09910  1132.61790 -159.93630  818.31170  1244.24820 -537.54360
# 781    1035.97670  1153.32510 -211.84930  847.33850  1252.54800 -555.84910
# ...           ...         ...        ...        ...         ...        ...
# 83634   799.71810   658.05383 -367.54132  733.67017   715.07666 -216.31491
# 83956   769.14374   574.88430 -499.84230  769.18665   614.30010 -272.73220
# 84272   797.32245  1266.40370  380.43887  680.01370  1261.02930  551.84300
# 84518   810.59470  1245.73140 -176.42027  688.43286  1289.56250 -244.97186
# 84756   795.20210  1279.59700  346.97750  611.13873  1293.00550  108.95325
#
# [598 rows x 102 columns]

# %%
# Videos gruppieren und in Liste schreiben
videos_raw = list(data.groupby(data.path))

len(videos_raw)
# Out:
# 599

# %% [markdown]
# ## 3.1 Pre-Processing-Funktionen

# %%
'''
Diese Funktion bringt die rohen Videos in eine neue Form, ohne die Videos zu schneiden.
Sie wird für den Sliding Window Ansatz benötigt.
Aus den rohen Videos werden nur noch die exrahierten Datenpunkte als Liste zurückgegeben.
'''
def remap_raw_videos(unmapped_videos):
    remapped_videos = []
    for video in unmapped_videos:
        v = video[1].reset_index()
        mapped_vid = v.loc[:, 'x_0':]
        remapped_videos.append(mapped_vid)
    return remapped_videos

# %%
'''
Schneiden der Videos

Diese Funktion bringt die rohen Videos in eine neue Form und schneidet sie eine bestimmte Anzahl Frames
vor und hinter dem vertikalen Höhepunkt der trinkenden Hand ab.

Aus den rohen Videos werden nur noch die exrahierten Datenpunkte als Liste zurückgegeben.

Inputs:
uncutted_videos: Die ungeschnittenen rohen Videos
n_frames: Die Anzahl der Frames, welche vor und nach dem Höchstpunkt der Hand (y_16) abgeschnitten werden sollen
'''
def cut_videos(uncutted_videos, n_frames=0):
    cut_videos = []
    for idx, video in enumerate(uncutted_videos):
        v = video[1].reset_index()
        # Position des höchsten Punktes (tiefster Wert, da tiefere Werte höhere vertikale Positionen aussagen)
        minpos = np.argmin(v.y_16)
        
        # Falls der Höhepunkt der Hand zu nahe am Beginn / Ende des Videos ist, ist die Trinkbewegung vermutlich nicht korrekt.
        # Das Video soll dann optimalerweise gelöscht werden.
        if((minpos < 20) or (len(v) - minpos < 20)):
            print('\033[91m' + 'Video mit dem Namen\n'
                  + videos_raw[idx][0]
                  + '\nund Index\n' + str(idx)
                  + '\nzeigt keine korrekte Trinkbewegung. Bitte entfernen.')
            
        cut_vid = v.loc[minpos-n_frames:minpos+n_frames, 'x_0':]   # Video x Frames vor und x Frames nach Höhepunkt der Hand (y_16) abschneiden
        cut_videos.append(cut_vid)
    return cut_videos

# %%
'''
Videos zentrieren

Diese Funktion zentriert alle Videos, in dem von allen Landmarks die Position des Kopfes im ersten Frame abgezogen wird.
'''
def center_data(uncentered_videos):
    centered_videos = []
    for video in uncentered_videos:
        centered_video = []
        # Position des Kopfes im ersten Frame des Videos bestimmen (x, y und z-Koordinate)
        head_start = video.loc[:,'x_0':'z_0'].values[0]
        for frame in np.array(video):
            centered_frame = []
            # Frame reshapen, sodass alle Landmarks als eine Liste zählen
            landmarks = frame.reshape((33, 3))
            for landmark in landmarks:
                centered_frame.append(landmark - head_start)
            centered_video.append(list(np.array(centered_frame).flatten()))
        centered_videos.append(centered_video)
    return centered_videos

# %%
'''
Relative Abstände

Diese Funktion berechnet den Abstand jedes Punktes des Skeletts zum Kopf und gibt diese anschliessend zurück.

Shape der Rückgabe: [x Anzahl Videos, x Anzahl Frames, 33 Datenpunkte]
'''
def calc_distances(raw_videos):
    # Abstand zu Kopf
    distances = []

    for video in raw_videos:
        frame_distances = []
        for frame in np.array(video):
            points = frame.reshape((33, 3))
            point_distances = []
            for k in range(len(points)):
                # Distanz einzeln von x-, y- und z-Koordinaten
                distance = points[k]-points[0]
                # Distanz mittels Formel berechnen
                point_distances.append(math.sqrt(distance[0] ** 2 + distance[1] ** 2 + distance[2] ** 2))
            frame_distances.append(point_distances)
        distances.append(frame_distances)
    return distances

# %%
'''
Diese Funktion gibt die Labels der Videos zurück.
1 = Compensation
0 = Natural
'''
def define_labels():
    labels = []

    for i in range(len(videos_raw)):
        labels.append(np.mean(videos_raw[i][1].compensation))
        
    return labels
labels = define_labels()

# %%
'''
Sliding Windows

Diese Funktion erstellt für alle Videos von unslided_videos Sliding Windows und gibt sie zurück.
Ausserdem werden die Labels auf die Sliding Windows korrekt verteilt.

Shape der Rückgabe: [x Anzahl Sliding Windows, {window_size} Anzahl Frames, 99 Datenpunkte]
'''
def create_sliding_windows(unslided_videos, window_size):
    videos_slided = []
    unslided_labels = define_labels()
    slided_labels = []
    for idx, unslided_video in enumerate(unslided_videos):
        video_label = unslided_labels[idx]
        for i in range(len(unslided_video) - window_size + 1):
            videos_slided.append(unslided_video[i:i+window_size])
            slided_labels.append(video_label)
    return videos_slided, slided_labels

# %%
'''
In dieser Funktion werden die Daten in eine geeignete Form gebracht.
Es werden die Values der einzelnen Videos in eine Liste geschrieben und zurückgegeben.
'''
def reshape_videos(unshaped_videos):
    reshaped_videos = []
    labels = []
    for video in unshaped_videos:
        reshaped_videos.append(video.values)
    return reshaped_videos

# %% [markdown]
# ## 3.2 Ansatz auswählen ✏️

# %%
# Ansatz 1: Absolute Datenpunkte mit geschnittenen Videos
videos = reshape_videos(cut_videos(videos_raw, n_frames=38))

# Ansatz 2: Zentrierte Datenpunkte mit geschnittenen Videos
# videos = center_data(cut_videos(videos_raw, n_frames=10))

# Ansatz 3: Relative Datenpunkte (Abstände zum Kopf) mit geschnittenen Videos
# videos = calc_distances(cut_videos(videos_raw, n_frames=10))

# Ansatz 4a: Sliding Windows mit absoluten Datenpunkten
# videos, labels = create_sliding_windows(remap_raw_videos(videos_raw), 10)

# Ansatz 4b: Sliding Windows mit zentrierten Datenpunkten
# videos, labels = create_sliding_windows(center_data(remap_raw_videos(videos_raw)), 10)

# Ansatz 4b: Sliding Windows mit relativen Datenpunkten
# videos, labels = create_sliding_windows(calc_distances(remap_raw_videos(videos_raw)), 10)

np.array(videos).shape
# Out:
# (599, 77, 99)

# %%
'''
Falls es zu einem Fehler kommt, kann folgende Zeile angepasst und auskommentiert werden, um ein falsches Video zu entfernen.
Alternativ kann das Video im Ordner gelöscht werden und die Datenpunkte neu extrahiert werden. ✏️
'''
# videos_raw.remove(videos_raw[144])
# Out:
# '\nFalls es zu einem Fehler kommt, kann folgende Zeile angepasst und auskommentiert werden, um ein falsches Video zu entfernen.\nAlternativ kann das Video im Ordner gelöscht werden und die Datenpunkte neu extrahiert werden. ✏️\n'

# %% [markdown]
# ## 3.3 Features und Labels definieren

# %%
# Features bestimmen
X = np.asarray(videos)
X.shape
# Out:
# (599, 77, 99)

# %%
# Labels setzen
y = np.array(labels)

y.shape
# Out:
# (599,)

# %%
# Daten in ein Trainings- und Testset unterteilen
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=4)

# Daten in ein Trainings- und Testset unterteilen
X_validate, X_test, y_validate, y_test = train_test_split(X_test, y_test, test_size=0.5, stratify=y_test, random_state=2)

# %%
# Verteilung der Testdaten
np.mean(y_test)
# Out:
# 0.5

# %% [markdown]
# # 4. Modelle trainieren

# %% [markdown]
# ## 4.1 LSTM

# %%
def define_lstm_model(input_shape, n_neurons=1):
    lstm_model = keras.Sequential()
    lstm_model.add(layers.LSTM(n_neurons, activation='relu', input_shape=input_shape))
    lstm_model.add(layers.Dense(1, activation='sigmoid'))
    return lstm_model

# %% [markdown]
# ## 4.2 RNN

# %%
def define_rnn_model(input_shape, n_neurons=1):
    rnn_model = keras.Sequential()
    rnn_model.add(layers.SimpleRNN(n_neurons, activation='relu', input_shape=input_shape))
    rnn_model.add(layers.Dense(1, activation='sigmoid'))
    return rnn_model

# %% [markdown]
# ## 4.3 Modell anwenden

# %%
'''
Gewünschtes Modell erstellen

Auskommentieren und Anzahl Neuronen anpassen (n_neurons)
input_shape wird automatisch übernommen
'''
# Anzahl Neuronen bestimmen ✏️
n_neurons=64

# LSTM
# model = define_lstm_model(n_neurons=n_neurons, input_shape=X.shape[1:])

# RNN
model = define_rnn_model(n_neurons=n_neurons, input_shape=X.shape[1:])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Modell kompilieren
model.compile(
    loss='binary_crossentropy',
    optimizer="Adam",
    metrics=['accuracy'],
)

# %%
# Modell trainieren
model.fit(
    X_train, y_train, validation_data=(X_validate, y_validate), epochs=1000
)
# validation_data=(X_validate, y_validate),
# Out:
# Epoch 1/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5597 - loss: 213.4558 - val_accuracy: 0.6667 - val_loss: 71.9483
# Epoch 2/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6010 - loss: 43.5212 - val_accuracy: 0.7556 - val_loss: 25.3991
# Epoch 3/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7641 - loss: 20.5987 - val_accuracy: 0.5333 - val_loss: 29.8916
# Epoch 4/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6634 - loss: 16.5181 - val_accuracy: 0.8111 - val_loss: 18.3245
# Epoch 5/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8337 - loss: 7.2422 - val_accuracy: 0.8111 - val_loss: 19.5876
# Epoch 6/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7966 - loss: 10.0639 - val_accuracy: 0.8000 - val_loss: 20.1477
# Epoch 7/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8272 - loss: 8.0450 - val_accuracy: 0.8444 - val_loss: 12.1848
# Epoch 8/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8848 - loss: 3.4098 - val_accuracy: 0.8222 - val_loss: 10.4877
# Epoch 9/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8953 - loss: 2.0346 - val_accuracy: 0.8333 - val_loss: 11.1539
# Epoch 10/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8909 - loss: 3.0674 - val_accuracy: 0.8444 - val_loss: 10.1141
# Epoch 11/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8861 - loss: 3.1051 - val_accuracy: 0.5222 - val_loss: 26.2346
# Epoch 12/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7783 - loss: 6.8924 - val_accuracy: 0.8333 - val_loss: 15.0146
# Epoch 13/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8610 - loss: 8.1052 - val_accuracy: 0.8556 - val_loss: 8.5149
# Epoch 14/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8905 - loss: 4.2832 - val_accuracy: 0.8778 - val_loss: 8.5783
# Epoch 15/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8903 - loss: 3.6900 - val_accuracy: 0.7889 - val_loss: 10.8490
# Epoch 16/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8777 - loss: 4.0929 - val_accuracy: 0.8667 - val_loss: 9.2426
# Epoch 17/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9194 - loss: 2.1720 - val_accuracy: 0.8889 - val_loss: 4.8107
# Epoch 18/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9250 - loss: 1.4349 - val_accuracy: 0.9222 - val_loss: 4.9468
# Epoch 19/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9201 - loss: 2.0232 - val_accuracy: 0.9222 - val_loss: 6.4173
# Epoch 20/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9232 - loss: 2.4368 - val_accuracy: 0.9000 - val_loss: 8.4369
# Epoch 21/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9313 - loss: 2.7115 - val_accuracy: 0.9000 - val_loss: 5.3221
# Epoch 22/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9542 - loss: 1.2988 - val_accuracy: 0.9222 - val_loss: 3.4887
# Epoch 23/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9494 - loss: 0.9173 - val_accuracy: 0.9444 - val_loss: 3.3870
# Epoch 24/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9534 - loss: 1.2283 - val_accuracy: 0.9111 - val_loss: 5.4505
# Epoch 25/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9339 - loss: 1.8830 - val_accuracy: 0.9111 - val_loss: 4.1951
# Epoch 26/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8981 - loss: 2.4479 - val_accuracy: 0.8444 - val_loss: 6.6608
# Epoch 27/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8781 - loss: 2.3937 - val_accuracy: 0.9000 - val_loss: 3.9628
# Epoch 28/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9528 - loss: 1.7962 - val_accuracy: 0.9111 - val_loss: 5.7989
# Epoch 29/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.9985 - val_accuracy: 0.6333 - val_loss: 9.9522
# Epoch 30/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8526 - loss: 3.7273 - val_accuracy: 0.9000 - val_loss: 4.5245
# Epoch 31/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9363 - loss: 2.3427 - val_accuracy: 0.9111 - val_loss: 5.1462
# Epoch 32/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8773 - loss: 4.4290 - val_accuracy: 0.9333 - val_loss: 3.9807
# Epoch 33/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9183 - loss: 3.3167 - val_accuracy: 0.9111 - val_loss: 3.7203
# Epoch 34/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9621 - loss: 0.7357 - val_accuracy: 0.9444 - val_loss: 3.1547
# Epoch 35/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9853 - loss: 0.3949 - val_accuracy: 0.9556 - val_loss: 1.7066
# Epoch 36/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9789 - loss: 0.8048 - val_accuracy: 0.9778 - val_loss: 1.6759
# Epoch 37/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9675 - loss: 0.5367 - val_accuracy: 0.9333 - val_loss: 2.0719
# Epoch 38/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9803 - loss: 0.2505 - val_accuracy: 0.9889 - val_loss: 1.3583
# Epoch 39/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9845 - loss: 0.6126 - val_accuracy: 0.9556 - val_loss: 1.6837
# Epoch 40/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9756 - loss: 0.4159 - val_accuracy: 0.9111 - val_loss: 3.8130
# Epoch 41/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9387 - loss: 0.9557 - val_accuracy: 0.9111 - val_loss: 4.5458
# Epoch 42/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9552 - loss: 1.7385 - val_accuracy: 0.9111 - val_loss: 3.9593
# Epoch 43/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9597 - loss: 0.8288 - val_accuracy: 0.9667 - val_loss: 1.8944
# Epoch 44/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9711 - loss: 0.3662 - val_accuracy: 0.9556 - val_loss: 1.9284
# Epoch 45/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9737 - loss: 0.2796 - val_accuracy: 0.9556 - val_loss: 1.8228
# Epoch 46/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9874 - loss: 0.1481 - val_accuracy: 0.9556 - val_loss: 1.5083
# Epoch 47/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9831 - loss: 0.3121 - val_accuracy: 0.9667 - val_loss: 1.4885
# Epoch 48/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9914 - loss: 0.1519 - val_accuracy: 0.9444 - val_loss: 2.0900
# Epoch 49/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9689 - loss: 0.3340 - val_accuracy: 0.9778 - val_loss: 1.6319
# Epoch 50/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9866 - loss: 0.4127 - val_accuracy: 0.9556 - val_loss: 1.7582
# Epoch 51/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9785 - loss: 0.3045 - val_accuracy: 0.9667 - val_loss: 1.4070
# Epoch 52/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9786 - loss: 0.3006 - val_accuracy: 0.9333 - val_loss: 2.5532
# Epoch 53/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9834 - loss: 0.6730 - val_accuracy: 0.9667 - val_loss: 1.4633
# Epoch 54/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9365 - loss: 1.1782 - val_accuracy: 0.9556 - val_loss: 1.9804
# Epoch 55/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9801 - loss: 0.5067 - val_accuracy: 0.9778 - val_loss: 1.3143
# Epoch 56/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0321 - val_accuracy: 0.9556 - val_loss: 1.4296
# Epoch 57/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9928 - loss: 0.0928 - val_accuracy: 0.9222 - val_loss: 2.4974
# Epoch 58/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9728 - loss: 0.2697 - val_accuracy: 0.9778 - val_loss: 1.4035
# Epoch 59/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9928 - loss: 0.1700 - val_accuracy: 0.9667 - val_loss: 1.6249
# Epoch 60/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0899 - val_accuracy: 0.9667 - val_loss: 1.6812
# Epoch 61/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9860 - loss: 0.1730 - val_accuracy: 0.9333 - val_loss: 2.0640
# Epoch 62/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9504 - loss: 0.7258 - val_accuracy: 0.9667 - val_loss: 1.5248
# Epoch 63/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9870 - loss: 0.1466 - val_accuracy: 0.9333 - val_loss: 2.5473
# Epoch 64/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9794 - loss: 0.3257 - val_accuracy: 0.9667 - val_loss: 2.0171
# Epoch 65/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9890 - loss: 0.2242 - val_accuracy: 0.9667 - val_loss: 1.4606
# Epoch 66/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9888 - loss: 0.1419 - val_accuracy: 0.9667 - val_loss: 1.4484
# Epoch 67/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9817 - loss: 0.3342 - val_accuracy: 0.6000 - val_loss: 11.5526
# Epoch 68/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8476 - loss: 4.8423 - val_accuracy: 0.9333 - val_loss: 2.1803
# Epoch 69/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9638 - loss: 0.5532 - val_accuracy: 0.9778 - val_loss: 1.2321
# Epoch 70/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9777 - loss: 0.4269 - val_accuracy: 0.9556 - val_loss: 1.5578
# Epoch 71/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9917 - loss: 0.1006 - val_accuracy: 0.9667 - val_loss: 1.4769
# Epoch 72/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9875 - loss: 0.1897 - val_accuracy: 0.9222 - val_loss: 1.9368
# Epoch 73/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9800 - loss: 0.2498 - val_accuracy: 0.9778 - val_loss: 1.2585
# Epoch 74/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9758 - loss: 0.4746 - val_accuracy: 0.9667 - val_loss: 1.6083
# Epoch 75/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9833 - loss: 0.1755 - val_accuracy: 0.9444 - val_loss: 1.6171
# Epoch 76/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9770 - loss: 0.2186 - val_accuracy: 0.9667 - val_loss: 1.6025
# Epoch 77/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9699 - loss: 0.6064 - val_accuracy: 0.9556 - val_loss: 1.2814
# Epoch 78/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9720 - loss: 0.5543 - val_accuracy: 0.9333 - val_loss: 2.1912
# Epoch 79/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9867 - loss: 0.3078 - val_accuracy: 0.9222 - val_loss: 3.2257
# Epoch 80/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9335 - loss: 1.2099 - val_accuracy: 0.8889 - val_loss: 5.1901
# Epoch 81/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9017 - loss: 2.4585 - val_accuracy: 0.8889 - val_loss: 8.1664
# Epoch 82/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9014 - loss: 3.1474 - val_accuracy: 0.6556 - val_loss: 17.9274
# Epoch 83/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8899 - loss: 4.2694 - val_accuracy: 0.9778 - val_loss: 0.9642
# Epoch 84/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8973 - loss: 3.2323 - val_accuracy: 0.9111 - val_loss: 4.6753
# Epoch 85/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9344 - loss: 1.4925 - val_accuracy: 0.9778 - val_loss: 1.3267
# Epoch 86/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9394 - loss: 1.1673 - val_accuracy: 0.9444 - val_loss: 4.5139
# Epoch 87/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9584 - loss: 1.2915 - val_accuracy: 0.8667 - val_loss: 3.1825
# Epoch 88/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 1.6732 - val_accuracy: 0.9556 - val_loss: 1.6657
# Epoch 89/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9766 - loss: 0.4367 - val_accuracy: 0.6667 - val_loss: 9.3733
# Epoch 90/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8482 - loss: 4.3703 - val_accuracy: 0.8778 - val_loss: 6.9793
# Epoch 91/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9257 - loss: 2.8645 - val_accuracy: 0.9778 - val_loss: 1.2658
# Epoch 92/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8776 - loss: 7.0583 - val_accuracy: 0.9556 - val_loss: 1.7376
# Epoch 93/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9575 - loss: 1.2999 - val_accuracy: 0.8556 - val_loss: 5.0142
# Epoch 94/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 1.2052 - val_accuracy: 0.9333 - val_loss: 1.7761
# Epoch 95/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9733 - loss: 0.4649 - val_accuracy: 0.9778 - val_loss: 0.9527
# Epoch 96/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9941 - loss: 0.1145 - val_accuracy: 0.9889 - val_loss: 0.6246
# Epoch 97/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9847 - loss: 0.2037 - val_accuracy: 0.9556 - val_loss: 0.6367
# Epoch 98/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9869 - loss: 0.4295 - val_accuracy: 0.9889 - val_loss: 0.6468
# Epoch 99/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9689 - loss: 0.8158 - val_accuracy: 0.9667 - val_loss: 0.6466
# Epoch 100/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9535 - loss: 1.3180 - val_accuracy: 0.9778 - val_loss: 0.5636
# Epoch 101/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9691 - loss: 0.9457 - val_accuracy: 0.9778 - val_loss: 0.1610
# Epoch 102/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9804 - loss: 0.4366 - val_accuracy: 0.8778 - val_loss: 3.8215
# Epoch 103/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9616 - loss: 0.9721 - val_accuracy: 0.9444 - val_loss: 1.2845
# Epoch 104/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9453 - loss: 1.3252 - val_accuracy: 0.9444 - val_loss: 1.8145
# Epoch 105/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9696 - loss: 1.1599 - val_accuracy: 0.9778 - val_loss: 0.6808
# Epoch 106/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9892 - loss: 0.2604 - val_accuracy: 0.9889 - val_loss: 0.8067
# Epoch 107/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9781 - loss: 0.6170 - val_accuracy: 0.9667 - val_loss: 0.8154
# Epoch 108/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9759 - loss: 0.6016 - val_accuracy: 0.9667 - val_loss: 0.9396
# Epoch 109/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9689 - loss: 0.4729 - val_accuracy: 0.9778 - val_loss: 0.7780
# Epoch 110/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9976 - loss: 0.0463 - val_accuracy: 0.9778 - val_loss: 1.2068
# Epoch 111/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9930 - loss: 0.2478 - val_accuracy: 0.9556 - val_loss: 0.6476
# Epoch 112/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9925 - loss: 0.2334 - val_accuracy: 0.9667 - val_loss: 0.5334
# Epoch 113/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9964 - loss: 0.0648 - val_accuracy: 0.9778 - val_loss: 0.7405
# Epoch 114/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9941 - loss: 0.0975 - val_accuracy: 0.9556 - val_loss: 0.9264
# Epoch 115/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9941 - loss: 0.1188 - val_accuracy: 0.9778 - val_loss: 0.6703
# Epoch 116/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9886 - loss: 0.4357 - val_accuracy: 0.9778 - val_loss: 0.5976
# Epoch 117/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9977 - loss: 0.0794 - val_accuracy: 0.9556 - val_loss: 0.8363
# Epoch 118/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.1968 - val_accuracy: 0.9889 - val_loss: 0.6204
# Epoch 119/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0651 - val_accuracy: 0.9667 - val_loss: 0.5724
# Epoch 120/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9953 - loss: 0.1032 - val_accuracy: 0.9889 - val_loss: 0.6768
# Epoch 121/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9897 - loss: 0.2438 - val_accuracy: 0.9778 - val_loss: 0.9550
# Epoch 122/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9887 - loss: 0.1490 - val_accuracy: 0.9556 - val_loss: 1.0806
# Epoch 123/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9772 - loss: 0.2692 - val_accuracy: 0.9667 - val_loss: 0.7840
# Epoch 124/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9961 - loss: 0.1011 - val_accuracy: 0.9556 - val_loss: 0.9721
# Epoch 125/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9857 - loss: 0.1930 - val_accuracy: 0.9222 - val_loss: 4.4426
# Epoch 126/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8805 - loss: 6.4186 - val_accuracy: 0.6889 - val_loss: 16.8157
# Epoch 127/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8727 - loss: 6.3964 - val_accuracy: 0.8333 - val_loss: 15.6075
# Epoch 128/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8160 - loss: 13.2980 - val_accuracy: 0.9111 - val_loss: 3.5855
# Epoch 129/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9489 - loss: 1.0619 - val_accuracy: 0.9333 - val_loss: 1.9561
# Epoch 130/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - loss: 0.2914 - val_accuracy: 0.9667 - val_loss: 1.6232
# Epoch 131/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9802 - loss: 0.7178 - val_accuracy: 0.9333 - val_loss: 2.6345
# Epoch 132/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9366 - loss: 1.8808 - val_accuracy: 0.9667 - val_loss: 1.9554
# Epoch 133/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9490 - loss: 1.1381 - val_accuracy: 0.9667 - val_loss: 1.7283
# Epoch 134/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9808 - loss: 0.5921 - val_accuracy: 0.9667 - val_loss: 0.8936
# Epoch 135/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9913 - loss: 0.1970 - val_accuracy: 0.9222 - val_loss: 2.7576
# Epoch 136/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9553 - loss: 0.7210 - val_accuracy: 0.9444 - val_loss: 1.7671
# Epoch 137/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9850 - loss: 0.6647 - val_accuracy: 0.9667 - val_loss: 1.0299
# Epoch 138/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9902 - loss: 0.2941 - val_accuracy: 0.9667 - val_loss: 1.3148
# Epoch 139/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9842 - loss: 0.6155 - val_accuracy: 0.9444 - val_loss: 1.8925
# Epoch 140/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9785 - loss: 0.9276 - val_accuracy: 0.9778 - val_loss: 1.4215
# Epoch 141/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9976 - loss: 0.1434 - val_accuracy: 0.9667 - val_loss: 1.4858
# Epoch 142/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9809 - loss: 0.8206 - val_accuracy: 0.9778 - val_loss: 0.8913
# Epoch 143/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9963 - loss: 0.1177 - val_accuracy: 0.9444 - val_loss: 1.8586
# Epoch 144/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9786 - loss: 0.3746 - val_accuracy: 0.9667 - val_loss: 1.4590
# Epoch 145/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9720 - loss: 0.8589 - val_accuracy: 0.9667 - val_loss: 1.6083
# Epoch 146/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0703 - val_accuracy: 0.9778 - val_loss: 0.8205
# Epoch 147/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9930 - loss: 0.2311 - val_accuracy: 0.9778 - val_loss: 0.8325
# Epoch 148/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9864 - loss: 0.3750 - val_accuracy: 0.9889 - val_loss: 0.7853
# Epoch 149/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9944 - loss: 0.2822 - val_accuracy: 0.9778 - val_loss: 0.9213
# Epoch 150/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - loss: 0.3824 - val_accuracy: 0.9778 - val_loss: 0.9846
# Epoch 151/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9896 - loss: 0.2245 - val_accuracy: 0.9667 - val_loss: 1.2178
# Epoch 152/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9915 - loss: 0.3129 - val_accuracy: 0.9556 - val_loss: 1.5735
# Epoch 153/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9852 - loss: 0.2644 - val_accuracy: 0.9556 - val_loss: 1.5718
# Epoch 154/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9867 - loss: 0.3179 - val_accuracy: 0.9667 - val_loss: 1.4639
# Epoch 155/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9901 - loss: 0.2406 - val_accuracy: 0.9444 - val_loss: 2.1258
# Epoch 156/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9855 - loss: 0.5053 - val_accuracy: 0.9556 - val_loss: 1.9730
# Epoch 157/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9873 - loss: 0.3977 - val_accuracy: 0.9667 - val_loss: 1.7814
# Epoch 158/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9939 - loss: 0.2020 - val_accuracy: 0.9111 - val_loss: 4.3500
# Epoch 159/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8318 - loss: 13.3767 - val_accuracy: 0.8889 - val_loss: 5.0875
# Epoch 160/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9280 - loss: 2.6439 - val_accuracy: 0.8667 - val_loss: 8.0719
# Epoch 161/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8721 - loss: 6.8389 - val_accuracy: 0.9444 - val_loss: 3.4758
# Epoch 162/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9357 - loss: 1.7609 - val_accuracy: 0.9444 - val_loss: 1.7702
# Epoch 163/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9476 - loss: 0.9958 - val_accuracy: 0.9667 - val_loss: 1.8538
# Epoch 164/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9897 - loss: 0.3546 - val_accuracy: 0.9556 - val_loss: 2.5661
# Epoch 165/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9654 - loss: 1.2262 - val_accuracy: 0.9556 - val_loss: 2.2649
# Epoch 166/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9517 - loss: 0.8901 - val_accuracy: 0.9667 - val_loss: 2.1292
# Epoch 167/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9722 - loss: 0.6827 - val_accuracy: 0.9333 - val_loss: 3.5052
# Epoch 168/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9594 - loss: 1.6263 - val_accuracy: 0.8556 - val_loss: 13.2208
# Epoch 169/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8866 - loss: 6.2052 - val_accuracy: 0.9556 - val_loss: 1.3736
# Epoch 170/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 1.2496 - val_accuracy: 0.9778 - val_loss: 1.3201
# Epoch 171/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9831 - loss: 0.4450 - val_accuracy: 0.9667 - val_loss: 2.1510
# Epoch 172/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9867 - loss: 0.6476 - val_accuracy: 0.9444 - val_loss: 1.6647
# Epoch 173/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9807 - loss: 0.5262 - val_accuracy: 0.9667 - val_loss: 1.6299
# Epoch 174/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9845 - loss: 0.2292 - val_accuracy: 0.9556 - val_loss: 1.9731
# Epoch 175/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9856 - loss: 0.2957 - val_accuracy: 0.9667 - val_loss: 1.8095
# Epoch 176/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9982 - loss: 0.1815 - val_accuracy: 0.9667 - val_loss: 1.7565
# Epoch 177/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9893 - loss: 0.2743 - val_accuracy: 0.9333 - val_loss: 3.1677
# Epoch 178/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9618 - loss: 0.9686 - val_accuracy: 0.9222 - val_loss: 1.9761
# Epoch 179/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9730 - loss: 0.7263 - val_accuracy: 0.9778 - val_loss: 1.4574
# Epoch 180/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9935 - loss: 0.1837 - val_accuracy: 0.9778 - val_loss: 1.4505
# Epoch 181/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9927 - loss: 0.1700 - val_accuracy: 0.9667 - val_loss: 1.4368
# Epoch 182/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9943 - loss: 0.4608 - val_accuracy: 0.9667 - val_loss: 1.2507
# Epoch 183/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9856 - loss: 0.4509 - val_accuracy: 0.9667 - val_loss: 1.6661
# Epoch 184/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9981 - loss: 0.0558 - val_accuracy: 0.9667 - val_loss: 1.8977
# Epoch 185/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9878 - loss: 0.3104 - val_accuracy: 0.9444 - val_loss: 1.9652
# Epoch 186/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9966 - loss: 0.1356 - val_accuracy: 0.8889 - val_loss: 3.0564
# Epoch 187/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9590 - loss: 1.1693 - val_accuracy: 0.9778 - val_loss: 1.5279
# Epoch 188/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9857 - loss: 0.1707 - val_accuracy: 0.9556 - val_loss: 1.9612
# Epoch 189/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.2330 - val_accuracy: 0.9778 - val_loss: 1.2724
# Epoch 190/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9935 - loss: 0.4214 - val_accuracy: 0.9556 - val_loss: 1.9562
# Epoch 191/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9802 - loss: 0.2218 - val_accuracy: 0.9556 - val_loss: 1.5859
# Epoch 192/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9863 - loss: 0.1603 - val_accuracy: 0.9556 - val_loss: 2.0400
# Epoch 193/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9874 - loss: 0.3975 - val_accuracy: 0.9667 - val_loss: 1.5696
# Epoch 194/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9877 - loss: 0.3278 - val_accuracy: 0.9556 - val_loss: 1.8636
# Epoch 195/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9972 - loss: 0.0512 - val_accuracy: 0.9667 - val_loss: 1.2155
# Epoch 196/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9914 - loss: 0.1928 - val_accuracy: 0.9556 - val_loss: 1.7587
# Epoch 197/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9901 - loss: 0.1064 - val_accuracy: 0.9778 - val_loss: 1.5074
# Epoch 198/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9909 - loss: 0.1415 - val_accuracy: 0.9667 - val_loss: 1.9199
# Epoch 199/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9889 - loss: 0.1199 - val_accuracy: 0.9556 - val_loss: 1.8400
# Epoch 200/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9976 - loss: 0.1100 - val_accuracy: 0.9778 - val_loss: 1.3627
# Epoch 201/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9884 - loss: 0.3967 - val_accuracy: 0.9444 - val_loss: 1.9451
# Epoch 202/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0522 - val_accuracy: 0.9667 - val_loss: 1.3892
# Epoch 203/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9816 - loss: 0.3426 - val_accuracy: 0.9556 - val_loss: 2.1009
# Epoch 204/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9607 - loss: 0.7219 - val_accuracy: 0.9778 - val_loss: 1.1098
# Epoch 205/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9705 - loss: 0.5755 - val_accuracy: 0.9667 - val_loss: 1.6133
# Epoch 206/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9952 - loss: 0.2444 - val_accuracy: 0.9667 - val_loss: 1.1405
# Epoch 207/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9885 - loss: 0.2900 - val_accuracy: 0.9778 - val_loss: 1.6638
# Epoch 208/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9809 - loss: 0.5485 - val_accuracy: 0.9778 - val_loss: 1.7221
# Epoch 209/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0814 - val_accuracy: 0.9667 - val_loss: 1.5629
# Epoch 210/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.0458 - val_accuracy: 0.9667 - val_loss: 1.5913
# Epoch 211/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9968 - loss: 0.1591 - val_accuracy: 0.9667 - val_loss: 1.4919
# Epoch 212/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.2269 - val_accuracy: 0.9778 - val_loss: 1.5038
# Epoch 213/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - loss: 0.1677 - val_accuracy: 0.9556 - val_loss: 1.9184
# Epoch 214/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.2299 - val_accuracy: 0.9556 - val_loss: 2.0586
# Epoch 215/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9769 - loss: 0.5323 - val_accuracy: 0.9222 - val_loss: 2.8217
# Epoch 216/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8166 - loss: 8.6878 - val_accuracy: 0.9778 - val_loss: 0.4866
# Epoch 217/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9812 - loss: 0.7320 - val_accuracy: 0.9667 - val_loss: 0.8377
# Epoch 218/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9743 - loss: 0.8872 - val_accuracy: 0.9889 - val_loss: 0.0343
# Epoch 219/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9905 - loss: 0.2402 - val_accuracy: 0.9778 - val_loss: 0.3932
# Epoch 220/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0573 - val_accuracy: 0.9667 - val_loss: 0.6751
# Epoch 221/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9911 - loss: 0.2573 - val_accuracy: 0.9556 - val_loss: 1.6914
# Epoch 222/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9773 - loss: 0.4034 - val_accuracy: 0.9667 - val_loss: 0.8588
# Epoch 223/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9856 - loss: 0.2072 - val_accuracy: 0.9667 - val_loss: 1.0351
# Epoch 224/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9928 - loss: 0.1856 - val_accuracy: 0.9778 - val_loss: 0.9012
# Epoch 225/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9855 - loss: 0.2250 - val_accuracy: 0.9556 - val_loss: 1.2220
# Epoch 226/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9915 - loss: 0.0793 - val_accuracy: 0.9667 - val_loss: 0.9574
# Epoch 227/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9985 - loss: 0.0587 - val_accuracy: 0.9667 - val_loss: 0.9287
# Epoch 228/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - loss: 0.0974 - val_accuracy: 0.9778 - val_loss: 0.7466
# Epoch 229/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9904 - loss: 0.0727 - val_accuracy: 0.9556 - val_loss: 1.1582
# Epoch 230/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.1800 - val_accuracy: 0.9667 - val_loss: 0.6983
# Epoch 231/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9968 - loss: 0.0274 - val_accuracy: 0.9778 - val_loss: 0.6873
# Epoch 232/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0028 - val_accuracy: 0.9778 - val_loss: 0.7498
# Epoch 233/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.0425 - val_accuracy: 0.9556 - val_loss: 0.8946
# Epoch 234/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.1030 - val_accuracy: 0.9667 - val_loss: 0.6973
# Epoch 235/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0172 - val_accuracy: 0.9778 - val_loss: 0.7184
# Epoch 236/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9862 - loss: 0.1190 - val_accuracy: 0.9556 - val_loss: 0.8414
# Epoch 237/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0037 - val_accuracy: 0.9444 - val_loss: 1.4982
# Epoch 238/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9874 - loss: 0.0818 - val_accuracy: 0.9667 - val_loss: 0.6669
# Epoch 239/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0011 - val_accuracy: 0.9778 - val_loss: 0.6008
# Epoch 240/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9978 - loss: 0.0364 - val_accuracy: 0.9556 - val_loss: 0.7247
# Epoch 241/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9969 - loss: 0.0448 - val_accuracy: 0.9667 - val_loss: 0.9461
# Epoch 242/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9985 - loss: 0.0071 - val_accuracy: 0.9556 - val_loss: 0.8488
# Epoch 243/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9822 - loss: 0.1305 - val_accuracy: 0.9667 - val_loss: 0.6203
# Epoch 244/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0236 - val_accuracy: 0.9889 - val_loss: 0.5577
# Epoch 245/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9936 - loss: 0.0191 - val_accuracy: 0.9444 - val_loss: 0.7676
# Epoch 246/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9900 - loss: 0.0516 - val_accuracy: 0.9778 - val_loss: 0.4451
# Epoch 247/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9959 - loss: 0.0335 - val_accuracy: 0.9444 - val_loss: 0.7757
# Epoch 248/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9846 - loss: 0.1006 - val_accuracy: 0.9778 - val_loss: 0.2795
# Epoch 249/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0216 - val_accuracy: 0.9778 - val_loss: 0.2600
# Epoch 250/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9949 - loss: 0.0319 - val_accuracy: 0.9333 - val_loss: 1.1953
# Epoch 251/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9813 - loss: 0.2171 - val_accuracy: 0.9556 - val_loss: 1.2053
# Epoch 252/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9900 - loss: 0.2469 - val_accuracy: 0.9667 - val_loss: 0.1793
# Epoch 253/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - loss: 0.0323 - val_accuracy: 0.9333 - val_loss: 1.2255
# Epoch 254/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9687 - loss: 0.2130 - val_accuracy: 0.9556 - val_loss: 1.1580
# Epoch 255/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9904 - loss: 0.0600 - val_accuracy: 0.9556 - val_loss: 0.7452
# Epoch 256/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9964 - loss: 0.0481 - val_accuracy: 0.9556 - val_loss: 0.8152
# Epoch 257/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9863 - loss: 0.1616 - val_accuracy: 0.9667 - val_loss: 0.6082
# Epoch 258/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9965 - loss: 0.0883 - val_accuracy: 0.9889 - val_loss: 0.5106
# Epoch 259/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9985 - loss: 0.0097 - val_accuracy: 0.9889 - val_loss: 0.3587
# Epoch 260/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9939 - loss: 0.0396 - val_accuracy: 0.9556 - val_loss: 0.6175
# Epoch 261/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9959 - loss: 0.0732 - val_accuracy: 0.9333 - val_loss: 2.0631
# Epoch 262/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9864 - loss: 0.1702 - val_accuracy: 0.9667 - val_loss: 1.0231
# Epoch 263/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.3627 - val_accuracy: 0.9778 - val_loss: 0.5474
# Epoch 264/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0201 - val_accuracy: 0.9444 - val_loss: 0.8295
# Epoch 265/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9895 - loss: 0.1677 - val_accuracy: 0.9667 - val_loss: 0.8473
# Epoch 266/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - loss: 0.2141 - val_accuracy: 0.9667 - val_loss: 0.2683
# Epoch 267/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - loss: 0.0621 - val_accuracy: 0.9667 - val_loss: 0.2417
# Epoch 268/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0031 - val_accuracy: 0.9778 - val_loss: 0.3419
# Epoch 269/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9993 - loss: 0.0235 - val_accuracy: 0.9778 - val_loss: 0.4213
# Epoch 270/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9969 - loss: 0.0142 - val_accuracy: 0.9667 - val_loss: 0.2668
# Epoch 271/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9985 - loss: 0.0115 - val_accuracy: 0.9667 - val_loss: 0.7868
# Epoch 272/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9935 - loss: 0.1930 - val_accuracy: 0.9667 - val_loss: 0.2947
# Epoch 273/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9940 - loss: 0.0294 - val_accuracy: 0.9778 - val_loss: 0.3856
# Epoch 274/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9963 - loss: 0.0511 - val_accuracy: 0.9667 - val_loss: 0.4435
# Epoch 275/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9927 - loss: 0.0284 - val_accuracy: 0.9667 - val_loss: 0.5942
# Epoch 276/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9966 - loss: 0.0524 - val_accuracy: 0.9778 - val_loss: 0.3358
# Epoch 277/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.8113e-04 - val_accuracy: 0.9778 - val_loss: 0.4321
# Epoch 278/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.5373e-06 - val_accuracy: 0.9667 - val_loss: 0.4601
# Epoch 279/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.6304e-05 - val_accuracy: 0.9667 - val_loss: 0.4659
# Epoch 280/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0399e-05 - val_accuracy: 0.9667 - val_loss: 0.4716
# Epoch 281/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.7527e-06 - val_accuracy: 0.9667 - val_loss: 0.4676
# Epoch 282/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0684e-05 - val_accuracy: 0.9667 - val_loss: 0.4611
# Epoch 283/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.1855e-05 - val_accuracy: 0.9667 - val_loss: 0.4557
# Epoch 284/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.1357e-05 - val_accuracy: 0.9667 - val_loss: 0.4529
# Epoch 285/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.3841e-05 - val_accuracy: 0.9667 - val_loss: 0.4513
# Epoch 286/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.2754e-05 - val_accuracy: 0.9667 - val_loss: 0.4505
# Epoch 287/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.2291e-06 - val_accuracy: 0.9667 - val_loss: 0.4496
# Epoch 288/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.3502e-06 - val_accuracy: 0.9667 - val_loss: 0.4493
# Epoch 289/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.6066e-06 - val_accuracy: 0.9667 - val_loss: 0.4480
# Epoch 290/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.3949e-06 - val_accuracy: 0.9667 - val_loss: 0.4474
# Epoch 291/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.8801e-06 - val_accuracy: 0.9667 - val_loss: 0.4470
# Epoch 292/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.6360e-06 - val_accuracy: 0.9667 - val_loss: 0.4462
# Epoch 293/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.3058e-05 - val_accuracy: 0.9667 - val_loss: 0.4454
# Epoch 294/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.4807e-06 - val_accuracy: 0.9667 - val_loss: 0.4365
# Epoch 295/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.4860e-05 - val_accuracy: 0.9667 - val_loss: 0.4357
# Epoch 296/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.3107e-06 - val_accuracy: 0.9667 - val_loss: 0.4362
# Epoch 297/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.1043e-06 - val_accuracy: 0.9667 - val_loss: 0.4365
# Epoch 298/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.1664e-05 - val_accuracy: 0.9667 - val_loss: 0.4379
# Epoch 299/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.7101e-06 - val_accuracy: 0.9667 - val_loss: 0.4378
# Epoch 300/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.7453e-06 - val_accuracy: 0.9667 - val_loss: 0.4383
# Epoch 301/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.2705e-06 - val_accuracy: 0.9667 - val_loss: 0.4385
# Epoch 302/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.5110e-06 - val_accuracy: 0.9667 - val_loss: 0.4376
# Epoch 303/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.4175e-06 - val_accuracy: 0.9667 - val_loss: 0.4333
# Epoch 304/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.0454e-06 - val_accuracy: 0.9667 - val_loss: 0.4325
# Epoch 305/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.2430e-06 - val_accuracy: 0.9667 - val_loss: 0.4338
# Epoch 306/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.3074e-06 - val_accuracy: 0.9667 - val_loss: 0.4368
# Epoch 307/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.8397e-06 - val_accuracy: 0.9667 - val_loss: 0.4370
# Epoch 308/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.8631e-06 - val_accuracy: 0.9667 - val_loss: 0.4371
# Epoch 309/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0247e-05 - val_accuracy: 0.9667 - val_loss: 0.4361
# Epoch 310/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 7.3692e-06 - val_accuracy: 0.9667 - val_loss: 0.4362
# Epoch 311/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.2526e-05 - val_accuracy: 0.9667 - val_loss: 0.4349
# Epoch 312/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.8550e-06 - val_accuracy: 0.9667 - val_loss: 0.4344
# Epoch 313/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.4101e-06 - val_accuracy: 0.9667 - val_loss: 0.4352
# Epoch 314/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.2117e-06 - val_accuracy: 0.9667 - val_loss: 0.4340
# Epoch 315/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.0635e-06 - val_accuracy: 0.9667 - val_loss: 0.4339
# Epoch 316/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.7944e-06 - val_accuracy: 0.9667 - val_loss: 0.4334
# Epoch 317/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.3130e-06 - val_accuracy: 0.9667 - val_loss: 0.4340
# Epoch 318/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.9884e-06 - val_accuracy: 0.9667 - val_loss: 0.4337
# Epoch 319/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.5659e-06 - val_accuracy: 0.9667 - val_loss: 0.4337
# Epoch 320/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.0947e-06 - val_accuracy: 0.9667 - val_loss: 0.4334
# Epoch 321/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.3745e-06 - val_accuracy: 0.9667 - val_loss: 0.4363
# Epoch 322/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.3416e-06 - val_accuracy: 0.9667 - val_loss: 0.4369
# Epoch 323/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.5843e-06 - val_accuracy: 0.9667 - val_loss: 0.4352
# Epoch 324/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.3154e-06 - val_accuracy: 0.9667 - val_loss: 0.4351
# Epoch 325/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.1130e-06 - val_accuracy: 0.9667 - val_loss: 0.4340
# Epoch 326/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.6207e-06 - val_accuracy: 0.9667 - val_loss: 0.4335
# Epoch 327/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.4094e-06 - val_accuracy: 0.9667 - val_loss: 0.4332
# Epoch 328/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.0606e-06 - val_accuracy: 0.9667 - val_loss: 0.4327
# Epoch 329/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.8214e-06 - val_accuracy: 0.9667 - val_loss: 0.4320
# Epoch 330/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.1333e-06 - val_accuracy: 0.9667 - val_loss: 0.4290
# Epoch 331/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.3364e-06 - val_accuracy: 0.9667 - val_loss: 0.4287
# Epoch 332/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.3339e-06 - val_accuracy: 0.9667 - val_loss: 0.4290
# Epoch 333/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.7914e-06 - val_accuracy: 0.9667 - val_loss: 0.4296
# Epoch 334/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 8.3436e-06 - val_accuracy: 0.9667 - val_loss: 0.4324
# Epoch 335/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.0013e-06 - val_accuracy: 0.9667 - val_loss: 0.4317
# Epoch 336/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.5607e-06 - val_accuracy: 0.9667 - val_loss: 0.4316
# Epoch 337/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.5777e-06 - val_accuracy: 0.9667 - val_loss: 0.4308
# Epoch 338/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.4474e-06 - val_accuracy: 0.9667 - val_loss: 0.4306
# Epoch 339/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.3779e-06 - val_accuracy: 0.9667 - val_loss: 0.4299
# Epoch 340/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.3927e-06 - val_accuracy: 0.9667 - val_loss: 0.4294
# Epoch 341/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.0146e-06 - val_accuracy: 0.9667 - val_loss: 0.4292
# Epoch 342/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.1168e-06 - val_accuracy: 0.9667 - val_loss: 0.4293
# Epoch 343/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.7474e-06 - val_accuracy: 0.9667 - val_loss: 0.4293
# Epoch 344/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.2393e-06 - val_accuracy: 0.9667 - val_loss: 0.4299
# Epoch 345/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.8977e-06 - val_accuracy: 0.9667 - val_loss: 0.4296
# Epoch 346/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.7054e-06 - val_accuracy: 0.9667 - val_loss: 0.4289
# Epoch 347/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.5966e-06 - val_accuracy: 0.9667 - val_loss: 0.4290
# Epoch 348/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.8881e-06 - val_accuracy: 0.9667 - val_loss: 0.4296
# Epoch 349/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.8954e-06 - val_accuracy: 0.9667 - val_loss: 0.4297
# Epoch 350/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.9811e-06 - val_accuracy: 0.9667 - val_loss: 0.4293
# Epoch 351/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.7669e-06 - val_accuracy: 0.9667 - val_loss: 0.4293
# Epoch 352/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.2424e-06 - val_accuracy: 0.9667 - val_loss: 0.4292
# Epoch 353/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.7975e-06 - val_accuracy: 0.9667 - val_loss: 0.4293
# Epoch 354/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.7489e-06 - val_accuracy: 0.9667 - val_loss: 0.4295
# Epoch 355/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.7781e-06 - val_accuracy: 0.9667 - val_loss: 0.4297
# Epoch 356/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.9416e-06 - val_accuracy: 0.9667 - val_loss: 0.4300
# Epoch 357/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.7070e-06 - val_accuracy: 0.9667 - val_loss: 0.4298
# Epoch 358/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.6974e-06 - val_accuracy: 0.9667 - val_loss: 0.4299
# Epoch 359/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.2112e-06 - val_accuracy: 0.9667 - val_loss: 0.4299
# Epoch 360/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.6020e-06 - val_accuracy: 0.9667 - val_loss: 0.4295
# Epoch 361/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.7675e-06 - val_accuracy: 0.9667 - val_loss: 0.4303
# Epoch 362/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.6731e-06 - val_accuracy: 0.9667 - val_loss: 0.4301
# Epoch 363/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.2392e-06 - val_accuracy: 0.9667 - val_loss: 0.4299
# Epoch 364/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.4073e-06 - val_accuracy: 0.9667 - val_loss: 0.4291
# Epoch 365/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.6419e-06 - val_accuracy: 0.9667 - val_loss: 0.4296
# Epoch 366/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.2901e-06 - val_accuracy: 0.9667 - val_loss: 0.4296
# Epoch 367/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.0458e-06 - val_accuracy: 0.9667 - val_loss: 0.4301
# ...
# Epoch 878/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9880 - loss: 0.6389 - val_accuracy: 0.9778 - val_loss: 0.3861
# Epoch 879/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9829 - loss: 0.3814 - val_accuracy: 0.9778 - val_loss: 0.2575
# Epoch 880/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9876 - loss: 0.3637 - val_accuracy: 0.9667 - val_loss: 0.8547
# Epoch 881/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9743 - loss: 0.3424 - val_accuracy: 0.9556 - val_loss: 0.5671
# Epoch 882/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9864 - loss: 0.3454 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 883/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9935 - loss: 0.2524 - val_accuracy: 0.9889 - val_loss: 0.0104
# Epoch 884/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9895 - loss: 0.3258 - val_accuracy: 0.9778 - val_loss: 0.3467
# Epoch 885/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9922 - loss: 0.2714 - val_accuracy: 0.9889 - val_loss: 0.2111
# Epoch 886/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0367 - val_accuracy: 0.9889 - val_loss: 0.3519
# Epoch 887/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9862 - loss: 0.5550 - val_accuracy: 0.9889 - val_loss: 0.1038
# Epoch 888/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9965 - loss: 0.1670 - val_accuracy: 0.9889 - val_loss: 0.2659
# Epoch 889/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9945 - loss: 0.0562 - val_accuracy: 0.9778 - val_loss: 0.1145
# Epoch 890/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9954 - loss: 0.1259 - val_accuracy: 0.9889 - val_loss: 0.2732
# Epoch 891/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9844 - loss: 0.6810 - val_accuracy: 0.9889 - val_loss: 0.2202
# Epoch 892/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9961 - loss: 0.1097 - val_accuracy: 0.9889 - val_loss: 0.3340
# Epoch 893/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9992 - loss: 0.0612 - val_accuracy: 0.9889 - val_loss: 0.1590
# Epoch 894/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9997 - loss: 0.1715 - val_accuracy: 0.8556 - val_loss: 1.9875
# Epoch 895/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8796 - loss: 2.9855 - val_accuracy: 0.9778 - val_loss: 0.3523
# Epoch 896/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9832 - loss: 0.2448 - val_accuracy: 0.9778 - val_loss: 0.4442
# Epoch 897/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9759 - loss: 0.7908 - val_accuracy: 0.9667 - val_loss: 0.1163
# Epoch 898/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9804 - loss: 0.3814 - val_accuracy: 0.9889 - val_loss: 0.2317
# Epoch 899/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9797 - loss: 0.3792 - val_accuracy: 0.9778 - val_loss: 0.5420
# Epoch 900/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9982 - loss: 0.0597 - val_accuracy: 0.9778 - val_loss: 0.1805
# Epoch 901/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9871 - loss: 0.2498 - val_accuracy: 0.9778 - val_loss: 0.4015
# Epoch 902/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9856 - loss: 0.3381 - val_accuracy: 0.9778 - val_loss: 0.0580
# Epoch 903/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9949 - loss: 0.1793 - val_accuracy: 0.9889 - val_loss: 0.2148
# Epoch 904/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9934 - loss: 0.2469 - val_accuracy: 0.9889 - val_loss: 0.3608
# Epoch 905/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9909 - loss: 0.5029 - val_accuracy: 0.9889 - val_loss: 0.1837
# Epoch 906/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9612 - loss: 0.9981 - val_accuracy: 0.9778 - val_loss: 0.9439
# Epoch 907/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9827 - loss: 0.2919 - val_accuracy: 0.9778 - val_loss: 0.6276
# Epoch 908/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9919 - loss: 0.3933 - val_accuracy: 0.9778 - val_loss: 0.6384
# Epoch 909/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - loss: 0.3912 - val_accuracy: 0.9778 - val_loss: 0.5871
# Epoch 910/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9915 - loss: 0.6985 - val_accuracy: 0.9778 - val_loss: 0.4987
# Epoch 911/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - loss: 0.4899 - val_accuracy: 0.9778 - val_loss: 0.9929
# Epoch 912/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9932 - loss: 0.1961 - val_accuracy: 0.9778 - val_loss: 0.6533
# Epoch 913/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.1240 - val_accuracy: 0.9778 - val_loss: 0.6915
# Epoch 914/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9956 - loss: 0.1750 - val_accuracy: 0.9778 - val_loss: 1.0116
# Epoch 915/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9931 - loss: 0.0804 - val_accuracy: 0.9778 - val_loss: 0.5569
# Epoch 916/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0445 - val_accuracy: 0.9778 - val_loss: 0.8015
# Epoch 917/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9930 - loss: 0.2020 - val_accuracy: 0.9889 - val_loss: 0.2840
# Epoch 918/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - loss: 0.2098 - val_accuracy: 0.9667 - val_loss: 1.4360
# Epoch 919/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9801 - loss: 0.2511 - val_accuracy: 0.9778 - val_loss: 0.6217
# Epoch 920/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9845 - loss: 0.2226 - val_accuracy: 0.9889 - val_loss: 0.3918
# Epoch 921/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9953 - loss: 0.1523 - val_accuracy: 0.9778 - val_loss: 0.4928
# Epoch 922/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.5225 - val_accuracy: 0.9778 - val_loss: 0.4324
# Epoch 923/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9979 - loss: 0.0892 - val_accuracy: 0.9778 - val_loss: 0.4647
# Epoch 924/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9977 - loss: 0.1288 - val_accuracy: 0.9778 - val_loss: 0.2433
# Epoch 925/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9903 - loss: 0.3185 - val_accuracy: 0.9556 - val_loss: 1.4622
# Epoch 926/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9844 - loss: 0.2813 - val_accuracy: 0.9889 - val_loss: 0.5351
# Epoch 927/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9912 - loss: 0.5019 - val_accuracy: 0.9889 - val_loss: 0.5899
# Epoch 928/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9987 - loss: 0.0956 - val_accuracy: 0.9778 - val_loss: 0.8094
# Epoch 929/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9870 - loss: 0.2094 - val_accuracy: 0.9889 - val_loss: 0.0938
# Epoch 930/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0851 - val_accuracy: 0.9667 - val_loss: 0.4670
# Epoch 931/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9826 - loss: 0.2670 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 932/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9908 - loss: 0.3871 - val_accuracy: 0.9889 - val_loss: 0.0851
# Epoch 933/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9956 - loss: 0.1473 - val_accuracy: 0.9333 - val_loss: 0.8570
# Epoch 934/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9770 - loss: 0.3677 - val_accuracy: 0.9889 - val_loss: 0.1502
# Epoch 935/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0266 - val_accuracy: 0.9556 - val_loss: 0.4671
# Epoch 936/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9851 - loss: 0.2592 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 937/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9969 - loss: 0.2446 - val_accuracy: 0.9667 - val_loss: 0.2918
# Epoch 938/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9940 - loss: 0.1372 - val_accuracy: 0.9889 - val_loss: 0.0483
# Epoch 939/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0410 - val_accuracy: 0.9778 - val_loss: 0.1599
# Epoch 940/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9834 - loss: 0.3023 - val_accuracy: 0.9667 - val_loss: 0.3099
# Epoch 941/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - loss: 0.2122 - val_accuracy: 0.9889 - val_loss: 0.3228
# Epoch 942/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9913 - loss: 0.2663 - val_accuracy: 0.9667 - val_loss: 0.3853
# Epoch 943/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9875 - loss: 0.2407 - val_accuracy: 0.9556 - val_loss: 1.1662
# Epoch 944/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9765 - loss: 0.3904 - val_accuracy: 0.9889 - val_loss: 0.5817
# Epoch 945/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9889 - loss: 0.3125 - val_accuracy: 0.9889 - val_loss: 0.5704
# Epoch 946/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9926 - loss: 0.1415 - val_accuracy: 0.9889 - val_loss: 0.5814
# Epoch 947/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9985 - loss: 0.0956 - val_accuracy: 0.9778 - val_loss: 0.7103
# Epoch 948/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0411 - val_accuracy: 0.9667 - val_loss: 0.8564
# Epoch 949/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9877 - loss: 0.1128 - val_accuracy: 0.9889 - val_loss: 0.4083
# Epoch 950/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.3536 - val_accuracy: 0.9889 - val_loss: 0.4590
# Epoch 951/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9840 - loss: 0.3127 - val_accuracy: 0.9889 - val_loss: 0.3159
# Epoch 952/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9950 - loss: 0.1539 - val_accuracy: 0.9667 - val_loss: 0.3698
# Epoch 953/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - loss: 0.0751 - val_accuracy: 0.9333 - val_loss: 1.4312
# Epoch 954/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9488 - loss: 0.8820 - val_accuracy: 0.9222 - val_loss: 1.9973
# Epoch 955/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9655 - loss: 1.0851 - val_accuracy: 0.9667 - val_loss: 0.6688
# Epoch 956/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9798 - loss: 0.2244 - val_accuracy: 0.9778 - val_loss: 0.2283
# Epoch 957/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.2520 - val_accuracy: 0.9889 - val_loss: 0.2733
# Epoch 958/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9934 - loss: 0.1059 - val_accuracy: 0.9778 - val_loss: 0.8337
# Epoch 959/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9354 - loss: 1.7119 - val_accuracy: 0.9444 - val_loss: 0.8671
# Epoch 960/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9857 - loss: 0.2863 - val_accuracy: 0.9444 - val_loss: 0.7538
# Epoch 961/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9594 - loss: 0.7645 - val_accuracy: 0.9889 - val_loss: 0.2834
# Epoch 962/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.6281 - val_accuracy: 1.0000 - val_loss: 5.3939e-05
# Epoch 963/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9806 - loss: 0.2666 - val_accuracy: 0.9889 - val_loss: 0.1042
# Epoch 964/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9925 - loss: 0.1331 - val_accuracy: 0.9889 - val_loss: 0.2648
# Epoch 965/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9961 - loss: 0.1073 - val_accuracy: 0.9889 - val_loss: 0.0875
# Epoch 966/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9985 - loss: 0.0612 - val_accuracy: 0.9778 - val_loss: 0.4894
# Epoch 967/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9762 - loss: 0.2659 - val_accuracy: 0.9889 - val_loss: 0.1307
# Epoch 968/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9895 - loss: 0.1802 - val_accuracy: 0.9667 - val_loss: 0.3841
# Epoch 969/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9861 - loss: 0.7990 - val_accuracy: 0.9778 - val_loss: 0.6054
# Epoch 970/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9801 - loss: 0.4386 - val_accuracy: 0.9889 - val_loss: 0.4726
# Epoch 971/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9815 - loss: 0.2516 - val_accuracy: 0.9889 - val_loss: 0.1098
# Epoch 972/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9963 - loss: 0.1021 - val_accuracy: 0.9889 - val_loss: 0.0596
# Epoch 973/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9817 - loss: 0.1735 - val_accuracy: 0.9889 - val_loss: 0.4555
# Epoch 974/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9981 - loss: 0.0911 - val_accuracy: 0.9778 - val_loss: 0.3732
# Epoch 975/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9734 - loss: 0.4218 - val_accuracy: 0.9667 - val_loss: 0.7820
# Epoch 976/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8424 - loss: 5.6191 - val_accuracy: 0.9889 - val_loss: 0.0255
# Epoch 977/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9175 - loss: 1.7172 - val_accuracy: 0.9889 - val_loss: 0.1632
# Epoch 978/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9558 - loss: 0.9979 - val_accuracy: 0.8778 - val_loss: 1.6274
# Epoch 979/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8501 - loss: 3.2493 - val_accuracy: 0.9111 - val_loss: 2.8933
# Epoch 980/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9443 - loss: 1.4268 - val_accuracy: 0.9667 - val_loss: 0.3353
# Epoch 981/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9695 - loss: 0.6046 - val_accuracy: 0.9889 - val_loss: 0.0128
# Epoch 982/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9765 - loss: 0.5217 - val_accuracy: 0.9778 - val_loss: 0.4292
# Epoch 983/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9777 - loss: 0.5547 - val_accuracy: 0.9889 - val_loss: 0.0589
# Epoch 984/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9849 - loss: 0.4118 - val_accuracy: 0.9667 - val_loss: 0.4922
# Epoch 985/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9918 - loss: 0.2547 - val_accuracy: 0.9889 - val_loss: 0.2666
# Epoch 986/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9860 - loss: 0.2721 - val_accuracy: 0.9889 - val_loss: 0.1588
# Epoch 987/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9872 - loss: 0.4502 - val_accuracy: 0.9778 - val_loss: 0.3793
# Epoch 988/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9779 - loss: 0.2895 - val_accuracy: 0.9889 - val_loss: 0.2595
# Epoch 989/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - loss: 0.1715 - val_accuracy: 0.9667 - val_loss: 0.4632
# Epoch 990/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9895 - loss: 0.2487 - val_accuracy: 0.9778 - val_loss: 0.2428
# Epoch 991/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9809 - loss: 0.4731 - val_accuracy: 0.9333 - val_loss: 1.9183
# Epoch 992/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9612 - loss: 1.6512 - val_accuracy: 0.9778 - val_loss: 0.7142
# Epoch 993/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9825 - loss: 0.3696 - val_accuracy: 0.9778 - val_loss: 0.1706
# Epoch 994/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9767 - loss: 0.4097 - val_accuracy: 0.9889 - val_loss: 0.1980
# Epoch 995/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9863 - loss: 0.2599 - val_accuracy: 0.9778 - val_loss: 0.0945
# Epoch 996/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9921 - loss: 0.2430 - val_accuracy: 0.9889 - val_loss: 0.1366
# Epoch 997/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9609 - loss: 1.0604 - val_accuracy: 0.9667 - val_loss: 1.1061
# Epoch 998/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9763 - loss: 0.5251 - val_accuracy: 0.9556 - val_loss: 0.2402
# Epoch 999/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9750 - loss: 0.6066 - val_accuracy: 0.9889 - val_loss: 0.2380
# Epoch 1000/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9942 - loss: 0.1711 - val_accuracy: 0.9778 - val_loss: 0.3541

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_4 (SimpleRNN)        │ (None, 64)             │        10,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,685 (123.77 KB)
#  Trainable params: 10,561 (41.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 21,124 (82.52 KB)

# %% [markdown]
# ### Modell speichern ✏️

# %%
# model_name = 'models/LSTM/lstm_a_cv_'
# model_name = 'models/RNN/rnn_a_cv_'
# model_name = 'models/sliding_window/sw_lstm_a_cv_'
model_name = 'models/sliding_window/sw_rnn_a_cv_'

# Wenn das Modell gespeichert werden soll, folgende Zeile auskommentieren:
# LEGACY
# model.save(model_name + str(X.shape[1]) + 'f_' + str(n_neurons) + 'n/' + 'model.h5')

model.save(model_name + str(X.shape[1]) + 'f_' + str(n_neurons) + 'n/' + 'my_model.keras')

# %% [markdown]
# ## 4.4 Hyperparametertuning

# %%
'''
Hyperparametertuning

Diese Funktion findet die Anzahl an Neuronen, welche das beste Resultat liefert.
'''
def tune_hyperparameters(untuned_model):
    # Regressor mit dem mitgegebenen Modell erstellen
    keras_regressor = keras.wrappers.scikit_learn.KerasRegressor(untuned_model)

    # Eine Suche mit dem Regressor erstellen. Es werden Werte der Neuronen zwischen 1 und 128 ausgewertet.
    randomized_search_cv = RandomizedSearchCV(
        keras_regressor,
        {"n_neurons": np.arange(1, 128)},
        n_iter=10,
        cv=3
    )
    
    randomized_search_cv.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=1000)
    
    print(randomized_search_cv.best_params_)
    
    return randomized_search_cv.best_estimator_.model

# %%
# Auskommentieren und Modell anpassen, um das beste Modell zu finden und zu speichern ✏️
# best_model = tune_hyperparameters(untuned_model=define_lstm_model)
# best_model.save('models/best_model')

# %% [markdown]
# # 5. Predictions

# %%
# Auskommentieren und ein bestimmtes Modell zu laden ✏️
# model = keras.models.load_model('models/RNN/rnn_a_cv_21f_32n')

# %%
result = model.predict(X_test)

# result
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# # 6. Evaluation

# %%
scores = model.evaluate(X_train, y_train, verbose=0)
print("In-Sample Accuracy: %.2f%%" % (scores[1]*100))
scores = model.evaluate(X_test, y_test, verbose=0)
print("Out-of-Sample Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# In-Sample Accuracy: 98.81%
# Out-of-Sample Accuracy: 98.89%

# %%
result = (result > 0.5).flatten()
actual = y_test > 0.5

# %%
confusion_matrix(actual, result)
# Out:
# array([[44,  1],
#        [ 0, 45]])

# %% [markdown]
# ## Evaluation eines einzelnen Videos

# %%
# Gewünschtes Sliding-Window-Modell auskommentieren ✏️

# model = keras.models.load_model('models/sliding_window/sw_rnn_a_cv_5f_64n')
# model = keras.models.load_model('models/sliding_window/sw_lstm_a_cv_5f_64n')

# model = keras.layers.TFSMLayer('models/sliding_window/sw_rnn_a_cv_10f_64n')
model = keras.models.load_model('models/sliding_window/sw_rnn_a_cv_77f_64n/my_model.keras')
# model = keras.models.load_model('models/sliding_window/sw_lstm_a_cv_10f_64n')
# model = keras.models.load_model('models/sliding_window/sw_rnn_a_cv_20f_64n')
# model = keras.models.load_model('models/sliding_window/sw_lstm_a_cv_20f_64n')

# %%
'''
Video klassifizieren

Diese Funktion berechnet für ein Video die Kompensationswahrscheinlichkeit

Input:
video_index: Index des Videos
window_size: Grösse der Sliding Windows

Output: Liste mit Wahrscheinlichkeiten für alle Sliding Windows der Videos
'''
def predict_video(video_index, window_size=5):
    return model.predict(np.array(create_sliding_windows(remap_raw_videos([videos_raw[video_index]]), window_size)[0]))

# %%
# Mit dem Durchschnitt der Klassifikationen kann der Anteil der Kompensation einer Trinkbewegung berechnet werden
comp_mean = np.mean(predict_video(video_index=225, window_size=10))
print("Anteil der Kompensation während des Trinkvorganges: %.2f%%" % (comp_mean*100))

comp_mean = np.mean(predict_video(video_index=523, window_size=10))
print("Anteil der Kompensation während des Trinkvorganges: %.2f%%" % (comp_mean*100))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Anteil der Kompensation während des Trinkvorganges: 80.50%
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step
# Anteil der Kompensation während des Trinkvorganges: 30.25%

# %%
'''
Darstellung der Kompensationswahrscheinlichkeit während der Trinkbewegung
'''
plt.plot(predict_video(video_index=225, window_size=10), label="Kompensation")
plt.plot(predict_video(video_index=523, window_size=10), label="Natürliche Bewegung")
plt.legend()
plt.title(label="Kompensationswahrscheinlichkeit während des Trinkverlaufes")
plt.xlabel('Frameanzahl')
plt.ylabel('Kompensationswahrscheinlichkeit')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# Text(0, 0.5, 'Kompensationswahrscheinlichkeit')

# %% [markdown]
# # 7. Darstellung des Trinkverlaufs

# %% [markdown]
# ![image.png](attachment:image.png)
# Quelle: https://google.github.io/mediapipe/solutions/pose.html

# %%
centered_videos = center_data(remap_raw_videos(videos_raw))
landmarks = list(data.columns)[3:]
video_keys = list(dict(videos_raw).keys())

# Plot der Trinkbewegung
def plot_landmark(video_index=525, landmark="y_0", plotlabel="Bewegung", title="Trinkbewegung"):
    landmark_movement = np.array(centered_videos[video_index])[:,landmarks.index(landmark)]
    plt.plot(landmark_movement, label=plotlabel)
    plt.legend()
    plt.title(label=title)
    plt.xlabel('Frameanzahl')
    plt.ylabel('Höhe des Landmarks')

# %%
# Hier kann durch ausprobieren ein Key gesucht werden
print("Video 1: " + videos_raw[523][0])
print("Video 2: " + videos_raw[223][0])

video_natural = video_keys.index('data/video/normal\drinking_normal00001.mp4')
video_compensation = video_keys.index('data/video/compensation\drinking_compensation00001.mp4')
# Out:
# Video 1: data/video/normal\drinking_normal00001.mp4
# Video 2: data/video/compensation\drinking_compensation00001.mp4

# %% [markdown]
# ## 7.1 Beispiele von Trinkbewegungen

# %%
plot_landmark(video_index=video_natural, landmark="y_14", plotlabel="Natürliche Trinkbewegung der rechten Hand")
plt.gca().invert_yaxis() # Die Y-Achse wird invertiert, da tiefere Koordinatenwerte höhrere Positionen bedeuten.

# %%
plot_landmark(video_index=video_natural, landmark="y_20", plotlabel="rechter Zeigefinger")
plot_landmark(video_index=video_natural, landmark="y_19", plotlabel="linker Zeigefinger")
plot_landmark(video_index=video_natural, landmark="y_10", plotlabel="Mund")
plot_landmark(video_index=video_natural, landmark="y_12", plotlabel="rechte Schulter")
plot_landmark(video_index=video_natural, landmark="y_14", plotlabel="rechter Ellbogen", title='Natürliche Trinkbewegung')
plt.gca().invert_yaxis() # Die Y-Achse wird invertiert, da tiefere Koordinatenwerte höhrere Positionen bedeuten.

# %%
plot_landmark(video_index=video_compensation, landmark="y_20", plotlabel="rechter Zeigefinger")
plot_landmark(video_index=video_compensation, landmark="y_19", plotlabel="linker Zeigefinger")
plot_landmark(video_index=video_compensation, landmark="y_10", plotlabel="Mund")
plot_landmark(video_index=video_compensation, landmark="y_12", plotlabel="rechte Schulter")
plot_landmark(video_index=video_compensation, landmark="y_14", plotlabel="rechter Ellbogen", title='Kompensierende Trinkbewegung')
plt.gca().invert_yaxis() # Die Y-Achse wird invertiert, da tiefere Koordinatenwerte höhrere Positionen bedeuten.

# %%
plot_landmark(video_index=video_natural, landmark="y_0", plotlabel="Natürliche Bewegung")
plot_landmark(video_index=video_compensation, landmark="y_0", plotlabel="Kompensierende Bewegung", title='Trinkbewegung des Kopfes')
plt.gca().invert_yaxis() # Die Y-Achse wird invertiert, da tiefere Koordinatenwerte höhrere Positionen bedeuten.

# Vertikale Linien, welche die Übergänge der Phasen der kompensierenden Bewegungen anzeigen
plt.axvline(64, lw=1, ls='--', c='grey')
plt.axvline(98, lw=1, ls='--', c='grey')
plt.axvline(112, lw=1, ls='--', c='grey')
plt.axvline(145, lw=1, ls='--', c='grey')

# %%
plot_landmark(video_index=video_natural, landmark="y_16", plotlabel="Natürliche Bewegung")
plot_landmark(video_index=video_compensation, landmark="y_16", plotlabel="Kompensierende Bewegung", title='Trinkbewegung des rechten Handgelenkes')
plt.gca().invert_yaxis() # Die Y-Achse wird invertiert, da tiefere Koordinatenwerte höhrere Positionen bedeuten.

# %%
plot_landmark(video_index=video_natural, landmark="x_16", plotlabel="Natürliche Trinkbewegung")
plot_landmark(video_index=video_compensation, landmark="x_16", plotlabel="Kompensierende Trinkbewegung", title="Horizontale Trinkbewegung des rechten Handgelenkes")

# %%
plot_landmark(video_index=video_natural, landmark="y_14", plotlabel="Natürliche Bewegung")
plot_landmark(video_index=video_compensation, landmark="y_14", plotlabel="Kompensierende Bewegung", title="Trinkbewegung des rechten Ellbogens (y_14)")
plt.gca().invert_yaxis() # Die Y-Achse wird invertiert, da tiefere Koordinatenwerte höhrere Positionen bedeuten.

# Vertikale Linien, welche die Übergänge der Phasen der natürlichen Bewegungen anzeigen
plt.axvline(45, lw=1, ls='--', c='grey')
plt.axvline(72, lw=1, ls='--', c='grey')
plt.axvline(90, lw=1, ls='--', c='grey')
plt.axvline(110, lw=1, ls='--', c='grey')

# %%
plot_landmark(video_index=video_natural, landmark="y_12", plotlabel="Natürliche Bewegung der rechten Schulter")
plot_landmark(video_index=video_compensation, landmark="y_12", plotlabel="Kompensierende Bewegung der rechten Schulter")
plot_landmark(video_index=video_compensation, landmark="y_0", plotlabel="Kompensierende Bewegung des Kopfes")
plt.gca().invert_yaxis() # Die Y-Achse wird invertiert, da tiefere Koordinatenwerte höhrere Positionen bedeuten.

# %%
plot_landmark(video_index=video_natural, landmark="y_12", plotlabel="Natürliche Trinkbewegung der rechten Schulter")
plot_landmark(video_index=video_natural, landmark="y_11", plotlabel="Natürliche Trinkbewegung der linken Schulter")
plt.gca().invert_yaxis() # Die Y-Achse wird invertiert, da tiefere Koordinatenwerte höhrere Positionen bedeuten.
